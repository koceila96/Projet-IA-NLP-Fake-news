# %% [markdown]
# `this nootbook has been created by IA-team
# `

# %%
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/__init__.py:24
#      23 try:
# ---> 24     from . import multiarray
#      25 except ImportError as exc:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/multiarray.py:10
#       9 import functools
# ---> 10 from . import overrides
#      11 from . import _multiarray_umath
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/overrides.py:8
#       7 from .._utils._inspect import getargspec
# ----> 8 from numpy.core._multiarray_umath import (
#       9     add_docstring,  _get_implementing_args, _ArrayFunctionDispatcher)
#      12 ARRAY_FUNCTIONS = set()
#
# ...

# %%
target = "class"
model_name = "data-cleaning"
project_name = "fake-news detection"

# %%
pd.set_option('display.max_colwidth', None)

# %%
df_fake = pd.read_csv("/Users/soufianebelhabibe/Desktop/IA-project/data/Fake.csv")
df_true = pd.read_csv("/Users/soufianebelhabibe/Desktop/IA-project/data/True.csv")

# %%
df_fake.head(5)
# Out:
#                                                                                         title  \
# 0              Donald Trump Sends Out Embarrassing New Year’s Eve Message; This is Disturbing
# 1                        Drunk Bragging Trump Staffer Started Russian Collusion Investigation
# 2   Sheriff David Clarke Becomes An Internet Joke For Threatening To Poke People ‘In The Eye’
# 3               Trump Is So Obsessed He Even Has Obama’s Name Coded Into His Website (IMAGES)
# 4                       Pope Francis Just Called Out Donald Trump During His Christmas Speech
#
# ...

# %%
df_true.head(5)
# Out:
#                                                                    title  \
# 0       As U.S. budget fight looms, Republicans flip their fiscal script
# 1       U.S. military to accept transgender recruits on Monday: Pentagon
# 2           Senior U.S. Republican senator: 'Let Mr. Mueller do his job'
# 3            FBI Russia probe helped by Australian diplomat tip-off: NYT
# 4  Trump wants Postal Service to charge 'much more' for Amazon shipments
#
# ...

# %%
df_fake.shape, df_true.shape
# Out:
# ((23481, 4), (21417, 4))

# %%
df_fake.describe()
# Out:
#                                                                                                         title  \
# count                                                                                                   23481
# unique                                                                                                  17903
# top     MEDIA IGNORES Time That Bill Clinton FIRED His FBI Director On Day Before Vince Foster Was Found Dead
# freq                                                                                                        6
#
#          text subject          date
# count   23481   23481         23481
# unique  17455       6          1681
# top              News  May 10, 2017
# freq      626    9050            46

# %%
# Insert the target class, for fake news class = 0 and for true mews class = 1 
df_fake["class"] = 0
df_true["class"] = 1

# %%
df_all = pd.concat([df_fake, df_true], axis= 0)
df_all.shape
# Out:
# (44898, 5)

# %%
target = "class"
df_all["class"].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
df_all.columns, df_all.head(5)
# Out:
# (Index(['title', 'text', 'subject', 'date', 'class'], dtype='object'),
#                                                                                          title  \
#  0              Donald Trump Sends Out Embarrassing New Year’s Eve Message; This is Disturbing
#  1                        Drunk Bragging Trump Staffer Started Russian Collusion Investigation
#  2   Sheriff David Clarke Becomes An Internet Joke For Threatening To Poke People ‘In The Eye’
#  3               Trump Is So Obsessed He Even Has Obama’s Name Coded Into His Website (IMAGES)
#  4                       Pope Francis Just Called Out Donald Trump During His Christmas Speech
#
# ...

# %%
data = df_all.copy()

# %%
data.drop(["title","subject","date"], axis=1, inplace=True)

# %%
data.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %%
data.isna().sum()
# Out:
# text     0
# class    0
# dtype: int64

# %% [markdown]
# ## Process the text

# %%
def wordopt(text) : 
    text = text.lower()
    text = re.sub('\[.*?]','', text)
    ext = re.sub("\\W"," ",text) 
    text = re.sub('https?://\S+|www\.\S+', '', text)
    text = re.sub('<.*?>+', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\n', '', text)
    text = re.sub('\w*\d\w*', '', text)    
    return text

# %%
data["text"] =data["text"].apply(wordopt)

# %%
data.head(2) # we have a clean text after applying the function
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %%
X = data["text"]
y = data["class"]

# %% [markdown]
# ## splitting and training

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True)

# %%
print(f"X_train shape :{X_train.shape}")
print(f"X_test  shape :{X_test.shape}")
print(f"y_train shape :{y_train.shape}")
print(f"y_test shape : {y_test.shape}")
# Out:
# X_train shape :(35918,)
# X_test  shape :(8980,)
# y_train shape :(35918,)
# y_test shape : (8980,)

# %%
export_folder = "/Users/soufianebelhabibe/Desktop/IA-project/data/data_prep/"

# %%
# Export des données divisées vers des fichiers CSV dans les dossiers spécifiés
X_train.to_csv(export_folder + 'X_train.csv', index=False)
X_test.to_csv(export_folder + 'X_test.csv', index=False)
y_train.to_csv(export_folder + 'y_train.csv', index=False)
y_test.to_csv(export_folder + 'y_test.csv', index=False)
